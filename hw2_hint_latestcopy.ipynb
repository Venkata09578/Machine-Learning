# %% [markdown]
# # HW 2: Analyzing IMDb Data
# Hint
# ---

# %% [markdown]
# There are multiple ways to solve this HW. This hint is just one of them. Hints to part 1 and 2 are provided here.

# %% [markdown]
# ## Part 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#1 Code to read csv file into colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#2. Get the file
#make sure you upload all your data files to your Google drive and change share->Advanced->change->anyone with the link can view
downloaded = drive.CreateFile({'id':'12oQVUx8gGsdruEi4iJB-KFvxLt3znK-l'}) # replace the id with id of file you want to access
downloaded.GetContentFile('imdb_1000.csv')

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('imdb_1000.csv')
movies.head()

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
#use shape
movies.shape

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
#use dataframe.dtypes

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
# column ='duration'
#use dataframe.duration.mean()
#use dataframe[column].mean()

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
# longest_index = dataframe.column.argmax() # or dataframe.column.idxmax()
# dataframe.iloc[longest_index]

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
# dataframe[column].hist(bins =?)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
# dataframe[column].boxplot()

# %% [markdown]
# ## Part 2

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
# dataframe[column].value_counts()

# %%
movies.head(2)

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
# temp = dataframe[column].value_counts()
# ax =temp.plot(kind='bar',title ='something')
# ax.set_xlabel('something')
# ax.set_ylabel('something')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
movies['content_rating'].unique()

# %%
# Answer:
# dataframe[column] = [ 'UNRATED' if ( (x =='something1') | (x =='something2')) else x for x in dataframe[column]]

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
#similar to above

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
#dataframe.isnull().sum()

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
#dataframe[column] = ['something reasonable' if pd.isnull(x) else x for x in dataframe[column]]

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
movies.head(2)

# %%
# Answer:
# long_movies = movies[movies[column]>=?]
# short_movies = movies[movies[column]<?]
# print(long_movies[column2].mean())
# print(short_movies[column2].mean())

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
# sns.heatmap(dataframe[[column1,column2]].corr())

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
# dataframe.groupby(column1)[column2].mean()

# %% [markdown]
# ## Part 3

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
# dataframe.boxplot(column=column1, by=column2) # or some other plots

# %%
movies.head()

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:
# dataframe_sorted = dataframe.sort_values(column1, ascending=False)
# dataframe_sorted.groupby(column2).head(1)

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
# dups = datframe[datframe[column1].duplicated(False)]
# dups # examine to conclude

# %%
movies.head()

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
movies['genre'].value_counts()

# %%
# Answer:
genre_count= dataframe['genre'].value_counts() # return a Series object
genre_list = pd.DataFrame({'genre':genre_count.index, 'count':genre_count.values})
genre_list_10 = genre_list[genre_list['count']>?] # filter it
g10list = genre_list_10.genre.unique().tolist() # convert it to a list, ['Drama', Action',...,'Mystery']
for x in g10list:
    ave = dataframe[dataframe.genre ==x]['star_rating'].mean()
    print (x, 'has avearge rating of:', ave)

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:
